# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\darkt\Dropbox\School\FA21\Codable\title.basics.tsv\title_basics.tsv", sep='\t')
# Out:
# C:\Users\darkt\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
rating = pd.read_csv(r"C:\Users\darkt\Documents\GitHub\ppt21\title.ratings.tsv\title_ratings.tsv", sep='\t')

# %%
rating.loc[rating['averageRating'] != '\\N']
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1823
# 1        tt0000002            6.0       233
# 2        tt0000003            6.5      1576
# 3        tt0000004            6.1       151
# 4        tt0000005            6.2      2402
# ...            ...            ...       ...
# 1191171  tt9916682            5.6         5
# 1191172  tt9916690            6.6         5
# 1191173  tt9916720            5.3       136
# 1191174  tt9916766            7.1        17
# 1191175  tt9916778            7.5        31
#
# [1191176 rows x 3 columns]

# %%
df = df.loc[(df['titleType'] == 'movie') & (df['runtimeMinutes'] != '\\N') ]
df = df.loc[(df['startYear'] != "\\N") & (df['endYear'] == "\\N")]
df['startYear'] = pd.to_numeric(df["startYear"])
df = df.loc[df['startYear'] >= 2000]

# %%
df.loc[df['primaryTitle'] != df['originalTitle']]
# Out:
#             tconst titleType  \
# 11059    tt0011216     movie
# 61125    tt0062336     movie
# 91086    tt0093119     movie
# 98065    tt0100275     movie
# 116013   tt0118694     movie
# ...            ...       ...
# 8316658  tt9914254     movie
# 8316988  tt9914942     movie
# 8317417  tt9915872     movie
# 8317558  tt9916170     movie
# 8317651  tt9916362     movie
#
#                                               primaryTitle  \
# 11059                                       Spanish Fiesta
# 61125    The Tango of the Widower and Its Distorting Mi...
# 91086                                  Grizzly II: Revenge
# 98065                             The Wandering Soap Opera
# 116013                                In the Mood for Love
# ...                                                    ...
# 8316658                                      A Cherry Tale
# 8316988                             Life Without Sara Amat
# 8317417                               The Last White Witch
# ...

# %%
temp = pd.merge(df, rating, how = 'inner', on = 'tconst')

# %%
temp.loc[temp['originalTitle'].str.contains('Harry Potter')]
# Out:
#            tconst titleType  \
# 1900    tt0241527     movie
# 5271    tt0295297     movie
# 5941    tt0304141     movie
# 7678    tt0330373     movie
# 10530   tt0373889     movie
# 13932   tt0417741     movie
# 25136   tt0926084     movie
# 38121   tt1201607     movie
# 60271   tt1781796     movie
# 62819   tt1867094     movie
# 122313  tt7783322     movie
# 125790  tt8443702     movie
#
#                                              primaryTitle  \
# 1900                Harry Potter and the Sorcerer's Stone
# 5271              Harry Potter and the Chamber of Secrets
# 5941             Harry Potter and the Prisoner of Azkaban
# 7678                  Harry Potter and the Goblet of Fire
# 10530           Harry Potter and the Order of the Phoenix
# 13932              Harry Potter and the Half-Blood Prince
# 25136        Harry Potter and the Deathly Hallows: Part 1
# 38121        Harry Potter and the Deathly Hallows: Part 2
# 60271   Creating the World of Harry Potter, Part 4: So...
# ...

# %%
import pandas as pd
import numpy as np

# %%
crew = pd.read_csv(r"C:\Users\darkt\Dropbox\School\FA21\Codable\title.crew.tsv\title_crew.tsv", sep='\t')
names = pd.read_csv(r"C:\Users\darkt\Dropbox\School\FA21\Codable\name.basics.tsv\name_basics.tsv", sep='\t')

# %%
crew
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# ...            ...                  ...                            ...
# 8315067  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8315068  tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8315069  tt9916852  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 8315070  tt9916856           nm10538645                      nm6951431
# 8315071  tt9916880            nm0996406            nm1482639,nm2586970
#
# [8315072 rows x 3 columns]

# %%
names
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 11263340  nm9993714   Romeo del Rosario        \N        \N
# 11263341  nm9993716       Essias Loberg        \N        \N
# 11263342  nm9993717  Harikrishnan Rajan        \N        \N
# 11263343  nm9993718         Aayush Nair        \N        \N
# 11263344  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# ...

# %%
pd.merge(crew, names, how = 'inner', left_on='directors', right_on='nconst')
# Out:
#             tconst   directors     writers      nconst           primaryName  \
# 0        tt0000001   nm0005690          \N   nm0005690  William K.L. Dickson
# 1        tt0000005   nm0005690          \N   nm0005690  William K.L. Dickson
# 2        tt0000006   nm0005690          \N   nm0005690  William K.L. Dickson
# 3        tt0000008   nm0005690          \N   nm0005690  William K.L. Dickson
# 4        tt0000036   nm0005690   nm0410331   nm0005690  William K.L. Dickson
# ...            ...         ...         ...         ...                   ...
# 3896078  tt9916696  nm10529675  nm10538344  nm10529675    Chaudhary Abhijeet
# 3896079  tt9916698  nm10439323  nm10439323  nm10439323     Kostas Antarachas
# 3896080  tt9916730  nm10538612  nm10538612  nm10538612          Kiran Gawade
# 3896081  tt9916756  nm10538639  nm10538639  nm10538639         Brianna Laren
# 3896082  tt9916856  nm10538645   nm6951431  nm10538645      Johan Planefeldt
#
# ...
